# %%
"""
FizzBuzz is the following problem:

For each of the numbers 1 to 100:
* if the number is divisible by 3, print "fizz"
* if the number is divisible by 5, print "buzz"
* if the number is divisible by 15, print "fizzbuzz"
* otherwise, just print the number
"""
from typing import List

import jax.numpy as np
import jax.random as jxr
import numpy as onp
from tqdm.autonotebook import tqdm

from colin_net.layers import Linear, Tanh, Softmax
from colin_net.nn import NeuralNet
from colin_net.data import BatchIterator
from colin_net.train import train
from colin_net.loss import mean_sqaured_error


key = jxr.PRNGKey(42)

def fizz_buzz_encode(x: int) -> List[int]:
    if x % 15 == 0:
        return [0, 0, 0, 1]
    elif x % 5 == 0:
        return [0, 0, 1, 0]
    elif x % 3 == 0:
        return [0, 1, 0, 0]
    else:
        return [1, 0, 0, 0]


def binary_encode(x: int) -> List[int]:
    """
    10 digit binary encoding of x
    """
    return [x >> i & 1 for i in range(10)]

inputs = np.array([
    binary_encode(x)
    for x in range(101, 1024)
])

targets = np.array([
    fizz_buzz_encode(x)
    for x in range(101, 1024)
])

net = NeuralNet([
    Linear.initialize(input_size=10, output_size=50, key=key),
    Tanh(),
    Linear.initialize(input_size=50, output_size=4, key=key),
    Softmax()
])

iterator = BatchIterator(inputs=inputs, targets=targets)


# define accuracy calculation
def accuracy(actual, predicted):
    return np.mean(np.argmax(actual, axis=1) == np.argmax(predicted, axis=1))



num_epochs = 5000

progress = train(net,
      loss=mean_sqaured_error,
      iterator=iterator,
      num_epochs=num_epochs,
      lr=0.001)


points = []
for i, (epoch, loss, net) in enumerate(tqdm(progress, total=num_epochs)):
    
    # check loss and accuracy every 5 epochs
    if i % 5 == 0:
        print(epoch, loss)
        predicted = net(inputs)

        if accuracy(targets, predicted) >= 0.99:
            print("Achieved Perfect Prediction!")
            points.append([epoch, loss])
            break
    points.append([epoch, loss])


for x in range(1, 101):
    predicted = net.predict(np.array(binary_encode(x)))
    predicted_idx = np.argmax(predicted)
    actual_idx = np.argmax(fizz_buzz_encode(x))
    labels = [str(x), "fizz", "buzz", "fizzbuzz"]
    print(x, labels[predicted_idx], labels[actual_idx])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5000.0), HTML(value='')))
# 0 9.955859
# 5 9.943995
# 10 9.931906
# 15 9.919583
# 20 9.907022
# 25 9.89421
# 30 9.881131
# 35 9.867778
# 40 9.854136
# 45 9.8401985
# 50 9.825954
# 55 9.811393
# 60 9.796512
# 65 9.781302
# 70 9.765763
# 75 9.749893
# 80 9.733696
# 85 9.7171755
# 90 9.700343
# 95 9.683205
# 100 9.665772
# 105 9.648065
# 110 9.630095
# 115 9.611877
# 120 9.593427
# 125 9.574757
# 130 9.5558815
# 135 9.536812
# 140 9.517549
# 145 9.498098
# 150 9.478463
# 155 9.458632
# 160 9.438606
# 165 9.418368
# 170 9.39791
# 175 9.3772135
# 180 9.356264
# 185 9.335031
# 190 9.313507
# 195 9.291674
# 200 9.269509
# 205 9.247008
# 210 9.224153
# 215 9.20093
# 220 9.1773405
# 225 9.153376
# 230 9.129044
# 235 9.104341
# 240 9.079286
# 245 9.05389
# 250 9.028173
# 255 9.002151
# 260 8.975837
# 265 8.94927
# 270 8.922459
# 275 8.895438
# 280 8.868224
# 285 8.840851
# 290 8.813335
# 295 8.785709
# 300 8.757987
# 305 8.730195
# 310 8.702343
# 315 8.674469
# 320 8.646584
# 325 8.618709
# 330 8.590871
# 335 8.56307
# 340 8.53535
# 345 8.507713
# 350 8.4802
# 355 8.452824
# 360 8.425627
# 365 8.398628
# 370 8.371863
# 375 8.345352
# 380 8.3191395
# 385 8.293239
# 390 8.267683
# 395 8.242507
# 400 8.217712
# 405 8.193324
# 410 8.169351
# 415 8.145778
# 420 8.122602
# 425 8.099827
# 430 8.077418
# 435 8.055349
# 440 8.033594
# 445 8.012111
# 450 7.990861
# 455 7.969803
# 460 7.9489107
# 465 7.92813
# 470 7.9074254
# 475 7.8867693
# 480 7.866132
# 485 7.8454933
# 490 7.824827
# 495 7.8041263
# 500 7.7834015
# 505 7.7626433
# 510 7.741882
# 515 7.721139
# 520 7.7004433
# 525 7.6798344
# 530 7.6593404
# 535 7.6390123
# 540 7.6188912
# 545 7.5990057
# 550 7.579383
# 555 7.5600643
# 560 7.5410705
# 565 7.522413
# 570 7.504106
# 575 7.4861684
# 580 7.4686027
# 585 7.4514117
# 590 7.4345922
# 595 7.4181466
# 600 7.402081
# 605 7.38639
# 610 7.3710785
# 615 7.356134
# 620 7.3415675
# 625 7.3273797
# 630 7.313562
# 635 7.300113
# 640 7.287027
# 645 7.27431
# 650 7.2619534
# 655 7.249955
# 660 7.238305
# 665 7.2269983
# 670 7.21603
# 675 7.2053895
# 680 7.1950617
# 685 7.185046
# 690 7.175326
# 695 7.1658936
# 700 7.1567388
# 705 7.147852
# 710 7.1392126
# 715 7.130812
# 720 7.122645
# 725 7.1146955
# 730 7.1069503
# 735 7.0994005
# 740 7.0920367
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4f6285c38c36> in <module>
#      77
#      78 points = []
# ---> 79 for i, (epoch, loss, net) in enumerate(tqdm(progress, total=num_epochs)):
#      80
#      81     # check loss and accuracy every 5 epochs
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/tqdm/notebook.py in __iter__(self, *args, **kwargs)
#     216     def __iter__(self, *args, **kwargs):
#     217         try:
# --> 218             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     219                 # return super(tqdm...) will not catch exception
#     220                 yield obj
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1125
#    1126         try:
# -> 1127             for obj in iterable:
#    1128                 yield obj
#    1129                 # Update and possibly print the progressbar.
#
# ~/Desktop/colin_net/colin_net/train.py in train(net, num_epochs, iterator, loss, lr)
#      26     for epoch in range(num_epochs):
#      27         epoch_loss = 0.0
# ---> 28         for batch in iterator:
#      29             epoch_loss += loss(net, batch.inputs, batch.targets)
#      30
#
# ~/Desktop/colin_net/colin_net/data.py in __iter__(self)
#      44             end = start + self.batch_size
#      45             batch_inputs = self.inputs[start:end]
# ---> 46             batch_targets = self.targets[start:end]
#      47             yield Batch(batch_inputs, batch_targets)
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in _rewriting_take(arr, idx)
#    3139   arr = asarray(arr)
#    3140   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx)
# -> 3141   return _gather(arr, treedef, static_idx, dynamic_idx)
#    3142
#    3143 # TODO(phawkins): re-enable jit after fixing excessive recompilation for
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in _gather(arr, treedef, static_idx, dynamic_idx)
#    3146 def _gather(arr, treedef, static_idx, dynamic_idx):
#    3147   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 3148   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    3149   y = arr
#    3150
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in _index_to_gather(x_shape, idx)
#    3268   start_index_map = []
#    3269
# -> 3270   index_dtype = int64 if max(x_shape) >= (1 << 31) else int32
#    3271   gather_indices = onp.zeros((0,), dtype=index_dtype)  # use onp to save a compilation
#    3272
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in reduction(a, axis, dtype, out, keepdims)
#    1463     a = lax.convert_element_type(a, computation_dtype)
#    1464     result = lax.reduce(a, _reduction_init_val(a, init_val),
# -> 1465                         op if computation_dtype != onp.bool_ else bool_op, dims)
#    1466     if keepdims:
#    1467       shape_with_singletons = subvals(shape(a), zip(dims, (1,) * len(dims)))
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/lax/lax.py in reduce(operand, init_value, computation, dimensions)
#    1007   monoid_reducer = _get_monoid_reducer(computation, init_value)
#    1008   if monoid_reducer:
# -> 1009     return monoid_reducer(operand, dimensions)
#    1010   else:
#    1011     jaxpr, consts = _reduction_jaxpr(computation, _abstractify(init_value))
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/lax/lax.py in _reduce_max(operand, axes)
#    1061
#    1062 def _reduce_max(operand: Array, axes: Sequence[int]) -> Array:
# -> 1063   return reduce_max_p.bind(operand, axes=tuple(axes))
#    1064
#    1065 def _reduce_min(operand: Array, axes: Sequence[int]) -> Array:
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/core.py in bind(self, *args, **kwargs)
#     197     top_trace = find_top_trace(args)
#     198     if top_trace is None:
# --> 199       return self.impl(*args, **kwargs)
#     200
#     201     tracers = map(top_trace.full_raise, args)
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/interpreters/xla.py in apply_primitive(prim, *args, **params)
#     165   """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
#     166   compiled_fun = xla_primitive_callable(prim, *map(arg_spec, args), **params)
# --> 167   return compiled_fun(*args)
#     168
#     169 @cache()
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/interpreters/xla.py in _execute_compiled_primitive(prim, compiled, result_handler, *args)
#     258   if FLAGS.jax_debug_nans:
#     259     check_nans(prim, out_bufs)
# --> 260   return result_handler(out_bufs if prim.multiple_results else out_bufs[0])
#     261
#     262 def _execute_replicated_primitive(prim, compiled, result_handler, *args):
#
# ~/.local/share/virtualenvs/colin_net-_rWhOUki/lib/python3.7/site-packages/jax/interpreters/xla.py in __init__(self, aval, device, lazy_expr, device_buffer)
#     740   __array_priority__ = 100
#     741
# --> 742   def __init__(self, aval, device, lazy_expr, device_buffer):
#     743     self.aval = aval
#     744     self.device_buffer = device_buffer
#
# KeyboardInterrupt:

# %%
accuracy(targets, net(inputs))
# Out:
# DeviceArray(0.42470205, dtype=float32)
